# %%
# shows the frequency of a value
import matplotlib.pyplot as plt

x = [23,45,64,21,35,56,86,34,63,23,54,57,78,2,47,9,36,10,28,47]

plt.hist(x, bins = 20, edgecolor = "black", color = "pink")
plt.show()
