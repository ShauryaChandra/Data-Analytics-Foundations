# %%
import matplotlib.pyplot as plt

brands = ["Samsung", "Apple", "Xiome", "Nokia", "Nothing"]

users = [35, 40, 10, 5, 10]

ex = [0, 0, 0, 0, 0.2]
plt.pie(users, labels = brands, explode = ex, shadow = True, autopct = "%.2f", startangle = 90)
plt.show
