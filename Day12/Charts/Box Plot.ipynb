# %%
"""
Box Plot:
1. Min (Lower Fence)
2. Quartile 1 -> 25%ile        formula = 25/100 x no. of values + 1
3. Median
4. Q3 -> 75%
5. Max (Upper Fence)
"""
import matplotlib.pyplot as plt

l = [1, 46, 4, 64, 34, 42, 23, 32, 35, 13, 15, 31, 20, 49, 50, 4, 7, 25, 46, 74, 24, 44, 19, 89]

plt.boxplot(l)
plt.show()
