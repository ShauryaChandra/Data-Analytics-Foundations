# %%
import pandas as pd

df = pd.read_excel("ESP.xlsx")
#display(df)

df.loc[(df["Bonus %"] < 9), "Get Bonus"] = "less bonus"
df.loc[(df["Bonus %"] >= 9), "Get Bonus"] = "bonus"
display(df.head(5))
# Out:
#      EEID       Full Name             Job Title Department  Bonus %  \
# 0  EMP001      Alex Patel  Marketing Specialist         HR    13.09
# 1  EMP002       Dev Mehta       Sales Executive    Finance    20.91
# 2  EMP003       Yash Nair       Product Manager         HR    10.72
# 3  EMP004  Shaurya Kapoor      Business Analyst    Product     8.22
# 4  EMP005      Neha Patel  Marketing Specialist    Finance    11.83
#
#         City  Country   Exit Date   Get Bonus
# 0     Jaipur      USA  2023-09-03       bonus
# 1  Ahmedabad  Germany         NaN       bonus
# 2  Bangalore    India         NaN       bonus
# 3    Chennai   Canada  2025-09-18  less bonus
# 4      Noida      USA         NaN       bonus

# %%
import pandas as pd

data = pd.read_csv("small_sample.csv")
display(data)

# if we want Name and Course in the same column
data["Name & Course"] = data["Name"] + " is learning " + data["Course"]
display(data)
# Out:
#    ID     Name  Age            Course  Marks
# 0   1  Shaurya   19            Python     88
# 1   2     Alex   20    Data Analytics     92
# 2   3     Riya   18  Machine Learning     85
# 3   4    Kabir   21        Statistics     79
# 4   5   Ananya   20               SQL     95
#    ID     Name  Age            Course  Marks  \
# 0   1  Shaurya   19            Python     88
# 1   2     Alex   20    Data Analytics     92
# 2   3     Riya   18  Machine Learning     85
# 3   4    Kabir   21        Statistics     79
# 4   5   Ananya   20               SQL     95
#
#                        Name & Course
# 0         Shaurya is learning Python
# 1    Alex is learning Data Analytics
# 2  Riya is learning Machine Learning
# 3       Kabir is learning Statistics
# 4             Ananya is learning SQL
