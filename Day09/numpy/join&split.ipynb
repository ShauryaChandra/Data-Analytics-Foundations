# %%
a = [50,60,70]
b = [34,67,65]
print(a+b)
# Out:
# [50, 60, 70, 34, 67, 65]

# %%
#Concatenate
import numpy as np
arr1 = np.array([[30,40], [45, 50]])
arr2 = np.array([[2,4], [6,5]])
print(np.concatenate([arr1,arr2]))
# Out:
# [[30 40]
#  [45 50]
#  [ 2  4]
#  [ 6  5]]

# %%
print(np.concatenate([arr1,arr2], axis =0))
# Out:
# [[30 40]
#  [45 50]
#  [ 2  4]
#  [ 6  5]]

# %%
print(np.concatenate([arr1,arr2], axis =1))
# Out:
# [[30 40  2  4]
#  [45 50  6  5]]

# %%
print(np.hstack([arr1,arr2]))    #Horizontal Concatenation
# Out:
# [[30 40  2  4]
#  [45 50  6  5]]

# %%
print(np.vstack([arr1,arr2]))   #Vertical Concatenation
# Out:
# [[30 40]
#  [45 50]
#  [ 2  4]
#  [ 6  5]]

# %%
a = np.array([10,20,30,40,50,60])
print(np.array_split(a,3))   # To split an array
# Out:
# [array([10, 20]), array([30, 40]), array([50, 60])]
