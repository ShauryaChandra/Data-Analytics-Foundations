# %%
import numpy as np

a = np.array([10,20,30,40])
print(np.append(a,90))

b = np.array([[10,20], [30,40]])
print(np.append(b,[66,89]))
# Out:
# [10 20 30 40 90]
# [10 20 30 40 66 89]

# %%
print(np.insert(a,1,25))   #Array,index,value
# Out:
# [10 25 20 30 40]

# %%
print(np.insert(b,1,[50,60], axis = 0))
# Out:
# [[10 20]
#  [50 60]
#  [30 40]]

# %%
print(np.delete(a,1))
# Out:
# [10 30 40]
