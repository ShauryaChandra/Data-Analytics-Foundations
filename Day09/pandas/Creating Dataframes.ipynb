# %%
import pandas as pd

data = {"Name" : ["Shaur", "Prayank", "Arnav"],
        "Age" : [20, 21, 19],
        "College" : ["MUJ", "DTU", "Jaypee"]}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age College
# 0    Shaur   20     MUJ
# 1  Prayank   21     DTU
# 2    Arnav   19  Jaypee

# %%
import pandas as pd
data = pd.read_excel("sample_learning_data.xlsx")
print(data)
# Out:
#    ID     Name  Age            Course  Marks
# 0   1  Shaurya   19            Python     88
# 1   2     Alex   20    Data Analytics     92
# 2   3     Riya   18  Machine Learning     85
# 3   4    Kabir   21        Statistics     79
# 4   5   Ananya   20               SQL     95
